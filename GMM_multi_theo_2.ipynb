# %% [markdown]
# ### GMM but multi-dimensional
# with theo's help, close to running
#
# Notes:
# I shouldn't use numpyro.param unless I am making my own guide, and I am

# %%
import jax
import jax.numpy as jnp
import numpy as np
import pandas as pd
from matplotlib import pyplot
# %matplotlib inline

import numpyro
import numpyro.distributions as dist
from numpyro.infer.autoguide import AutoDiagonalNormal
from numpyro.infer import SVI, Trace_ELBO

# %%
df = pd.read_csv('/Users/victorlhoste/Desktop/Local_PhD/NHANES/Data/data_pyro.csv', index_col=0)
df.head()
# Out:
#    height        bmi      WHtR  hba1c     hdl  non_hdl  sbp  dbp        eGFR  \
# 1   178.8  25.524376  0.496644    5.3  0.9842   5.9570  117   59   95.625163
# 2   162.2  23.433188  0.557953    4.6  1.4245   2.7195  130   88  114.670330
# 3   156.9  27.642813  0.570427    5.3  1.7094   4.4030  134   75   87.324169
# 4   177.4  29.392363  0.576099    4.6  1.1137   4.7138  135   94   77.957926
# 5   168.2  24.954721  0.558859    9.1  1.3209   5.4131  121   69   79.104629
#
#   age_group
# 1     Young
# 2     Young
# 3   Middage
# 4     Young
# 5   Middage

# %%
df = df[["height","bmi","WHtR","hba1c","hdl","non_hdl","sbp","dbp","eGFR"]]
d=9 # dimension
df_centered = df.apply(lambda x: (x - x.mean())/x.std() )
#print(df_centered)
# data=torch.tensor(df_centered.values)
data=df_centered
data.shape
# Out:
# (58876, 9)

# %%
# data.mean(axis=0)
key = jax.random.PRNGKey(1) ### needed for Jax otherwise it doesn't run
dist.MultivariateNormal(
    jnp.zeros(9),
    (0.5*jnp.eye(9))
).sample(key, (1,))
# Out:
# DeviceArray([[ 0.4884729 , -0.34467286, -0.8172662 ,  0.08561976,
#                0.8492481 , -0.35912296,  0.6474882 ,  1.2089263 ,
#               -0.25985762]], dtype=float32)

# %%
data
# Out:
#           height       bmi      WHtR     hba1c       hdl   non_hdl       sbp  \
# 1       1.168186 -0.456668 -0.925723 -0.336735 -0.915115  1.936171 -0.392283
# 2      -0.483296 -0.783355 -0.279489 -0.986232  0.150982 -0.940821  0.275890
# 3      -1.010577 -0.125724 -0.148007 -0.336735  0.840810  0.555215  0.481481
# 4       1.028905  0.147592 -0.088218 -0.986232 -0.601557  0.831406  0.532879
# 5       0.113625 -0.545659 -0.269946  3.189105 -0.099864  1.452837 -0.186692
# ...          ...       ...       ...       ...       ...       ...       ...
# 121359  1.297519 -0.740389 -1.156648  0.034406  1.279791 -0.411455 -0.083896
# 121362 -1.050372 -1.318701 -0.624310  1.611755  0.464540 -1.999555  0.841267
# 121363 -0.214682  1.151621  1.177504  0.219977 -0.225287 -0.296375 -0.289487
# 121364 -0.443502 -0.361139 -0.559742 -0.429520  0.088271 -0.641614 -0.443681
# 121366  0.869726  1.191959  1.154219 -0.243950 -1.165961 -0.388439  1.149654
#
#              dbp      eGFR
# 1      -1.058891  0.186490
# 2       1.343212  0.960026
# 3       0.266407 -0.150661
# 4       1.840198 -0.531079
# 5      -0.230580 -0.484505
# ...          ...       ...
# 121359  0.597732  0.077173
# 121362  0.100745 -0.130726
# 121363  0.266407  0.459758
# 121364  0.100745  1.394330
# 121366  1.923029  0.860760
#
# [58876 rows x 9 columns]

# %%
np.asarray(data)
# Out:
# array([[ 1.16818633, -0.45666756, -0.92572325, ..., -0.39228322,
#         -1.05889073,  0.18649042],
#        [-0.48329643, -0.78335454, -0.27948912, ...,  0.27588975,
#          1.34321152,  0.96002567],
#        [-1.01057707, -0.12572355, -0.14800652, ...,  0.48148143,
#          0.26640706, -0.15066133],
#        ...,
#        [-0.21468176,  1.15162078,  1.17750434, ..., -0.28948738,
#          0.26640706,  0.45975806],
#        [-0.44350166, -0.36113942, -0.55974171, ..., -0.44368114,
#          0.10074484,  1.39432987],
#        [ 0.86972559,  1.19195885,  1.15421921, ...,  1.1496544 ,
#          1.9230293 ,  0.86075981]])

# %%
## Multivaiate model
# I think I have some issues with the priors

 # Fixed number of components.

def model(K,h,data=None):
    # Global variables.
    weights = numpyro.sample('weights', dist.Dirichlet(0.5 * jnp.ones(K)))
    scale = numpyro.sample('scale', dist.HalfNormal(2.)) # same variance paramter for all clusters
    with numpyro.plate('components', K):
        locs=numpyro.sample('locs',dist.MultivariateNormal(jnp.zeros(h),jnp.eye(h))) #  weird

    with numpyro.plate('data', len(data)):
        # Local variables
        assignment = numpyro.sample('assignment', dist.Categorical(weights))
        numpyro.sample('obs', dist.MultivariateNormal(locs[assignment], scale*jnp.eye(h)), obs=data)

# %%
key = jax.random.PRNGKey(3)
h=9
locs=dist.MultivariateNormal(jnp.zeros(h),jnp.eye(h)).expand([2]).sample(key)
dist.MultivariateNormal(locs[1], 0.5*jnp.eye(h)).sample(key)
# Out:
# DeviceArray([ 1.5053518 ,  0.48227185, -0.984928  , -0.25600165,
#               0.43856192, -1.2653244 , -1.2724206 ,  1.7150483 ,
#               0.0498327 ], dtype=float32)

# %%
### This is running the model without any data just to make sure that the shape of the different objects are correct
# there is no fitting here


with numpyro.handlers.seed(rng_seed=1):
    trace = numpyro.handlers.trace(model).get_trace(data=np.asarray(data),K=3,h=9)
print(numpyro.util.format_shapes(trace))
# Out:
#    Trace Shapes:
#     Param Sites:
#    Sample Sites:
#     weights dist       | 3
#            value       | 3
#       scale dist       |
#            value       |
# components plate     3 |
#        locs dist     3 | 9
#            value     3 | 9
#       data plate 58876 |
#  assignment dist 58876 |
#            value 58876 |
#         obs dist 58876 | 9
#            value 58876 | 9

# %%
numpyro.render_model(model, model_args=(3,9,np.asarray(data)))

# %%
guide = AutoDiagonalNormal(model) # The guide is what is doing the variational inference instead of the MCMC, basically fitting a distribution on the param to estimate (I think)
optimizer = numpyro.optim.Adam(step_size=0.001) # Step size is the learning rate, you want to start low and increase
svi = SVI(model, guide, optimizer, loss=Trace_ELBO())

# %%
rng_key = jax.random.PRNGKey(0) # Specificity of Jax (the tensor flow equivalent I think), you need to set the seed and use it in the line after

svi_result = svi.run(rng_key, 10000,K=5,h=9,data= np.asarray(data))
params = svi_result.params
# Out:
# /var/folders/81/b4cplk1j4x11rl7011b9bpx40000gn/T/ipykernel_10926/3324042575.py:3: FutureWarning: Some algorithms will automatically enumerate the discrete latent site assignment of your model. In the future, enumerated sites need to be marked with `infer={'enumerate': 'parallel'}`.
#   svi_result = svi.run(rng_key, 10000,K=5,h=9,data= np.asarray(data))
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/opt/anaconda3/envs/bayesian/lib/python3.9/site-packages/numpyro/distributions/transforms.py:1044, in ConstraintRegistry.__call__(self, constraint)
#    <a href='file:///~/opt/anaconda3/envs/bayesian/lib/python3.9/site-packages/numpyro/distributions/transforms.py?line=1042'>1043</a> try:
# -> <a href='file:///~/opt/anaconda3/envs/bayesian/lib/python3.9/site-packages/numpyro/distributions/transforms.py?line=1043'>1044</a>     factory = self._registry[type(constraint)]
#    <a href='file:///~/opt/anaconda3/envs/bayesian/lib/python3.9/site-packages/numpyro/distributions/transforms.py?line=1044'>1045</a> except KeyError as e:
#
# KeyError: <class 'numpyro.distributions.constraints._IntegerInterval'>
#
# The above exception was the direct cause of the following exception:
#
# NotImplementedError                       Traceback (most recent call last)
# File ~/opt/anaconda3/envs/bayesian/lib/python3.9/site-packages/numpyro/infer/util.py:1050, in helpful_support_errors(site, raise_warnings)
#    <a href='file:///~/opt/anaconda3/envs/bayesian/lib/python3.9/site-packages/numpyro/infer/util.py?line=1048'>1049</a> try:
# -> <a href='file:///~/opt/anaconda3/envs/bayesian/lib/python3.9/site-packages/numpyro/infer/util.py?line=1049'>1050</a>     yield
#    <a href='file:///~/opt/anaconda3/envs/bayesian/lib/python3.9/site-packages/numpyro/infer/util.py?line=1050'>1051</a> except NotImplementedError as e:
#
# File ~/opt/anaconda3/envs/bayesian/lib/python3.9/site-packages/numpyro/infer/autoguide.py:177, in AutoGuide._setup_prototype(self, *args, **kwargs)
#     <a href='file:///~/opt/anaconda3/envs/bayesian/lib/python3.9/site-packages/numpyro/infer/autoguide.py?line=175'>176</a>     with helpful_support_errors(site):
# --> <a href='file:///~/opt/anaconda3/envs/bayesian/lib/python3.9/site-packages/numpyro/infer/autoguide.py?line=176'>177</a>         biject_to(site["fn"].support)
#     <a href='file:///~/opt/anaconda3/envs/bayesian/lib/python3.9/site-packages/numpyro/infer/autoguide.py?line=177'>178</a> for frame in site["cond_indep_stack"]:
#
# File ~/opt/anaconda3/envs/bayesian/lib/python3.9/site-packages/numpyro/distributions/transforms.py:1046, in ConstraintRegistry.__call__(self, constraint)
#    <a href='file:///~/opt/anaconda3/envs/bayesian/lib/python3.9/site-packages/numpyro/distributions/transforms.py?line=1044'>1045</a> except KeyError as e:
# -> <a href='file:///~/opt/anaconda3/envs/bayesian/lib/python3.9/site-packages/numpyro/distributions/transforms.py?line=1045'>1046</a>     raise NotImplementedError from e
#    <a href='file:///~/opt/anaconda3/envs/bayesian/lib/python3.9/site-packages/numpyro/distributions/transforms.py?line=1047'>1048</a> return factory(constraint)
#
# NotImplementedError:
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# /Users/victorlhoste/Desktop/Pyro_git/Git/Bayeian_clustering_RFs/GMM_multi_theo.ipynb Cell 13' in <module>
#       <a href='vscode-notebook-cell:/Users/victorlhoste/Desktop/Pyro_git/Git/Bayeian_clustering_RFs/GMM_multi_theo.ipynb#ch0000012?line=0'>1</a> rng_key = jax.random.PRNGKey(0) # Specificity of Jax (the tensor flow equivalent I think), you need to set the seed and use it in the line after
# ----> <a href='vscode-notebook-cell:/Users/victorlhoste/Desktop/Pyro_git/Git/Bayeian_clustering_RFs/GMM_multi_theo.ipynb#ch0000012?line=2'>3</a> svi_result = svi.run(rng_key, 10000,K=5,h=9,data= np.asarray(data))
#       <a href='vscode-notebook-cell:/Users/victorlhoste/Desktop/Pyro_git/Git/Bayeian_clustering_RFs/GMM_multi_theo.ipynb#ch0000012?line=3'>4</a> params = svi_result.params
#
# File ~/opt/anaconda3/envs/bayesian/lib/python3.9/site-packages/numpyro/infer/svi.py:342, in SVI.run(self, rng_key, num_steps, progress_bar, stable_update, init_state, *args, **kwargs)
#     <a href='file:///~/opt/anaconda3/envs/bayesian/lib/python3.9/site-packages/numpyro/infer/svi.py?line=338'>339</a>     return svi_state, loss
#     <a href='file:///~/opt/anaconda3/envs/bayesian/lib/python3.9/site-packages/numpyro/infer/svi.py?line=340'>341</a> if init_state is None:
# --> <a href='file:///~/opt/anaconda3/envs/bayesian/lib/python3.9/site-packages/numpyro/infer/svi.py?line=341'>342</a>     svi_state = self.init(rng_key, *args, **kwargs)
#     <a href='file:///~/opt/anaconda3/envs/bayesian/lib/python3.9/site-packages/numpyro/infer/svi.py?line=342'>343</a> else:
#     <a href='file:///~/opt/anaconda3/envs/bayesian/lib/python3.9/site-packages/numpyro/infer/svi.py?line=343'>344</a>     svi_state = init_state
#
# File ~/opt/anaconda3/envs/bayesian/lib/python3.9/site-packages/numpyro/infer/svi.py:180, in SVI.init(self, rng_key, *args, **kwargs)
#     <a href='file:///~/opt/anaconda3/envs/bayesian/lib/python3.9/site-packages/numpyro/infer/svi.py?line=177'>178</a> model_init = seed(self.model, model_seed)
#     <a href='file:///~/opt/anaconda3/envs/bayesian/lib/python3.9/site-packages/numpyro/infer/svi.py?line=178'>179</a> guide_init = seed(self.guide, guide_seed)
# --> <a href='file:///~/opt/anaconda3/envs/bayesian/lib/python3.9/site-packages/numpyro/infer/svi.py?line=179'>180</a> guide_trace = trace(guide_init).get_trace(*args, **kwargs, **self.static_kwargs)
#     <a href='file:///~/opt/anaconda3/envs/bayesian/lib/python3.9/site-packages/numpyro/infer/svi.py?line=180'>181</a> model_trace = trace(replay(model_init, guide_trace)).get_trace(
#     <a href='file:///~/opt/anaconda3/envs/bayesian/lib/python3.9/site-packages/numpyro/infer/svi.py?line=181'>182</a>     *args, **kwargs, **self.static_kwargs
#     <a href='file:///~/opt/anaconda3/envs/bayesian/lib/python3.9/site-packages/numpyro/infer/svi.py?line=182'>183</a> )
#     <a href='file:///~/opt/anaconda3/envs/bayesian/lib/python3.9/site-packages/numpyro/infer/svi.py?line=183'>184</a> params = {}
#
# File ~/opt/anaconda3/envs/bayesian/lib/python3.9/site-packages/numpyro/handlers.py:171, in trace.get_trace(self, *args, **kwargs)
#     <a href='file:///~/opt/anaconda3/envs/bayesian/lib/python3.9/site-packages/numpyro/handlers.py?line=162'>163</a> def get_trace(self, *args, **kwargs):
#     <a href='file:///~/opt/anaconda3/envs/bayesian/lib/python3.9/site-packages/numpyro/handlers.py?line=163'>164</a>     """
#     <a href='file:///~/opt/anaconda3/envs/bayesian/lib/python3.9/site-packages/numpyro/handlers.py?line=164'>165</a>     Run the wrapped callable and return the recorded trace.
#     <a href='file:///~/opt/anaconda3/envs/bayesian/lib/python3.9/site-packages/numpyro/handlers.py?line=165'>166</a>
#    (...)
#     <a href='file:///~/opt/anaconda3/envs/bayesian/lib/python3.9/site-packages/numpyro/handlers.py?line=168'>169</a>     :return: `OrderedDict` containing the execution trace.
#     <a href='file:///~/opt/anaconda3/envs/bayesian/lib/python3.9/site-packages/numpyro/handlers.py?line=169'>170</a>     """
# --> <a href='file:///~/opt/anaconda3/envs/bayesian/lib/python3.9/site-packages/numpyro/handlers.py?line=170'>171</a>     self(*args, **kwargs)
#     <a href='file:///~/opt/anaconda3/envs/bayesian/lib/python3.9/site-packages/numpyro/handlers.py?line=171'>172</a>     return self.trace
#
# File ~/opt/anaconda3/envs/bayesian/lib/python3.9/site-packages/numpyro/primitives.py:105, in Messenger.__call__(self, *args, **kwargs)
#     <a href='file:///~/opt/anaconda3/envs/bayesian/lib/python3.9/site-packages/numpyro/primitives.py?line=102'>103</a>     return self
#     <a href='file:///~/opt/anaconda3/envs/bayesian/lib/python3.9/site-packages/numpyro/primitives.py?line=103'>104</a> with self:
# --> <a href='file:///~/opt/anaconda3/envs/bayesian/lib/python3.9/site-packages/numpyro/primitives.py?line=104'>105</a>     return self.fn(*args, **kwargs)
#
# File ~/opt/anaconda3/envs/bayesian/lib/python3.9/site-packages/numpyro/primitives.py:105, in Messenger.__call__(self, *args, **kwargs)
#     <a href='file:///~/opt/anaconda3/envs/bayesian/lib/python3.9/site-packages/numpyro/primitives.py?line=102'>103</a>     return self
#     <a href='file:///~/opt/anaconda3/envs/bayesian/lib/python3.9/site-packages/numpyro/primitives.py?line=103'>104</a> with self:
# --> <a href='file:///~/opt/anaconda3/envs/bayesian/lib/python3.9/site-packages/numpyro/primitives.py?line=104'>105</a>     return self.fn(*args, **kwargs)
#
# File ~/opt/anaconda3/envs/bayesian/lib/python3.9/site-packages/numpyro/infer/autoguide.py:557, in AutoContinuous.__call__(self, *args, **kwargs)
#     <a href='file:///~/opt/anaconda3/envs/bayesian/lib/python3.9/site-packages/numpyro/infer/autoguide.py?line=553'>554</a> def __call__(self, *args, **kwargs):
#     <a href='file:///~/opt/anaconda3/envs/bayesian/lib/python3.9/site-packages/numpyro/infer/autoguide.py?line=554'>555</a>     if self.prototype_trace is None:
#     <a href='file:///~/opt/anaconda3/envs/bayesian/lib/python3.9/site-packages/numpyro/infer/autoguide.py?line=555'>556</a>         # run model to inspect the model structure
# --> <a href='file:///~/opt/anaconda3/envs/bayesian/lib/python3.9/site-packages/numpyro/infer/autoguide.py?line=556'>557</a>         self._setup_prototype(*args, **kwargs)
#     <a href='file:///~/opt/anaconda3/envs/bayesian/lib/python3.9/site-packages/numpyro/infer/autoguide.py?line=558'>559</a>     latent = self._sample_latent(*args, **kwargs)
#     <a href='file:///~/opt/anaconda3/envs/bayesian/lib/python3.9/site-packages/numpyro/infer/autoguide.py?line=560'>561</a>     # unpack continuous latent samples
#
# File ~/opt/anaconda3/envs/bayesian/lib/python3.9/site-packages/numpyro/infer/autoguide.py:519, in AutoContinuous._setup_prototype(self, *args, **kwargs)
#     <a href='file:///~/opt/anaconda3/envs/bayesian/lib/python3.9/site-packages/numpyro/infer/autoguide.py?line=517'>518</a> def _setup_prototype(self, *args, **kwargs):
# --> <a href='file:///~/opt/anaconda3/envs/bayesian/lib/python3.9/site-packages/numpyro/infer/autoguide.py?line=518'>519</a>     super()._setup_prototype(*args, **kwargs)
#     <a href='file:///~/opt/anaconda3/envs/bayesian/lib/python3.9/site-packages/numpyro/infer/autoguide.py?line=519'>520</a>     self._init_latent, shape_dict = _ravel_dict(self._init_locs)
#     <a href='file:///~/opt/anaconda3/envs/bayesian/lib/python3.9/site-packages/numpyro/infer/autoguide.py?line=520'>521</a>     unpack_latent = partial(_unravel_dict, shape_dict=shape_dict)
#
# File ~/opt/anaconda3/envs/bayesian/lib/python3.9/site-packages/numpyro/infer/autoguide.py:177, in AutoGuide._setup_prototype(self, *args, **kwargs)
#     <a href='file:///~/opt/anaconda3/envs/bayesian/lib/python3.9/site-packages/numpyro/infer/autoguide.py?line=173'>174</a> if not site["is_observed"] and site["fn"].support.is_discrete:
#     <a href='file:///~/opt/anaconda3/envs/bayesian/lib/python3.9/site-packages/numpyro/infer/autoguide.py?line=174'>175</a>     # raise support errors early for discrete sites
#     <a href='file:///~/opt/anaconda3/envs/bayesian/lib/python3.9/site-packages/numpyro/infer/autoguide.py?line=175'>176</a>     with helpful_support_errors(site):
# --> <a href='file:///~/opt/anaconda3/envs/bayesian/lib/python3.9/site-packages/numpyro/infer/autoguide.py?line=176'>177</a>         biject_to(site["fn"].support)
#     <a href='file:///~/opt/anaconda3/envs/bayesian/lib/python3.9/site-packages/numpyro/infer/autoguide.py?line=177'>178</a> for frame in site["cond_indep_stack"]:
#     <a href='file:///~/opt/anaconda3/envs/bayesian/lib/python3.9/site-packages/numpyro/infer/autoguide.py?line=178'>179</a>     if frame.name in self._prototype_frames:
#
# File ~/opt/anaconda3/envs/bayesian/lib/python3.9/contextlib.py:137, in _GeneratorContextManager.__exit__(self, typ, value, traceback)
#     <a href='file:///~/opt/anaconda3/envs/bayesian/lib/python3.9/contextlib.py?line=134'>135</a>     value = typ()
#     <a href='file:///~/opt/anaconda3/envs/bayesian/lib/python3.9/contextlib.py?line=135'>136</a> try:
# --> <a href='file:///~/opt/anaconda3/envs/bayesian/lib/python3.9/contextlib.py?line=136'>137</a>     self.gen.throw(typ, value, traceback)
#     <a href='file:///~/opt/anaconda3/envs/bayesian/lib/python3.9/contextlib.py?line=137'>138</a> except StopIteration as exc:
#     <a href='file:///~/opt/anaconda3/envs/bayesian/lib/python3.9/contextlib.py?line=138'>139</a>     # Suppress StopIteration *unless* it's the same exception that
#     <a href='file:///~/opt/anaconda3/envs/bayesian/lib/python3.9/contextlib.py?line=139'>140</a>     # was passed to throw().  This prevents a StopIteration
#     <a href='file:///~/opt/anaconda3/envs/bayesian/lib/python3.9/contextlib.py?line=140'>141</a>     # raised inside the "with" statement from being suppressed.
#     <a href='file:///~/opt/anaconda3/envs/bayesian/lib/python3.9/contextlib.py?line=141'>142</a>     return exc is not value
#
# File ~/opt/anaconda3/envs/bayesian/lib/python3.9/site-packages/numpyro/infer/util.py:1055, in helpful_support_errors(site, raise_warnings)
#    <a href='file:///~/opt/anaconda3/envs/bayesian/lib/python3.9/site-packages/numpyro/infer/util.py?line=1051'>1052</a> support_name = repr(support).lower()
#    <a href='file:///~/opt/anaconda3/envs/bayesian/lib/python3.9/site-packages/numpyro/infer/util.py?line=1052'>1053</a> if "integer" in support_name or "boolean" in support_name:
#    <a href='file:///~/opt/anaconda3/envs/bayesian/lib/python3.9/site-packages/numpyro/infer/util.py?line=1053'>1054</a>     # TODO: mention enumeration when it is supported in SVI
# -> <a href='file:///~/opt/anaconda3/envs/bayesian/lib/python3.9/site-packages/numpyro/infer/util.py?line=1054'>1055</a>     raise ValueError(
#    <a href='file:///~/opt/anaconda3/envs/bayesian/lib/python3.9/site-packages/numpyro/infer/util.py?line=1055'>1056</a>         f"Continuous inference cannot handle discrete sample site '{name}'."
#    <a href='file:///~/opt/anaconda3/envs/bayesian/lib/python3.9/site-packages/numpyro/infer/util.py?line=1056'>1057</a>     )
#    <a href='file:///~/opt/anaconda3/envs/bayesian/lib/python3.9/site-packages/numpyro/infer/util.py?line=1057'>1058</a> if "sphere" in support_name:
#    <a href='file:///~/opt/anaconda3/envs/bayesian/lib/python3.9/site-packages/numpyro/infer/util.py?line=1058'>1059</a>     raise ValueError(
#    <a href='file:///~/opt/anaconda3/envs/bayesian/lib/python3.9/site-packages/numpyro/infer/util.py?line=1059'>1060</a>         f"Continuous inference cannot handle spherical sample site '{name}'. "
#    <a href='file:///~/opt/anaconda3/envs/bayesian/lib/python3.9/site-packages/numpyro/infer/util.py?line=1060'>1061</a>         "Consider using ProjectedNormal distribution together with "
#    <a href='file:///~/opt/anaconda3/envs/bayesian/lib/python3.9/site-packages/numpyro/infer/util.py?line=1061'>1062</a>         "a reparameterizer, e.g. "
#    <a href='file:///~/opt/anaconda3/envs/bayesian/lib/python3.9/site-packages/numpyro/infer/util.py?line=1062'>1063</a>         f"numpyro.handlers.reparam(config={{'{name}': ProjectedNormalReparam()}})."
#    <a href='file:///~/opt/anaconda3/envs/bayesian/lib/python3.9/site-packages/numpyro/infer/util.py?line=1063'>1064</a>     )
#
# ValueError: Continuous inference cannot handle discrete sample site 'assignment'.

# %%
guide.sample_posterior(
    jax.random.PRNGKey(1), params, sample_shape=(1000,)
)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /Users/victorlhoste/Desktop/Multiple_sub_groups_Pyro_git/Git/Bayeian_clustering_RFs/GMM_multi copy.ipynb Cell 13' in <module>
#       <a href='vscode-notebook-cell:/Users/victorlhoste/Desktop/Multiple_sub_groups_Pyro_git/Git/Bayeian_clustering_RFs/GMM_multi%20copy.ipynb#ch0000012?line=0'>1</a> guide.sample_posterior(
# ----> <a href='vscode-notebook-cell:/Users/victorlhoste/Desktop/Multiple_sub_groups_Pyro_git/Git/Bayeian_clustering_RFs/GMM_multi%20copy.ipynb#ch0000012?line=1'>2</a>     jax.random.PRNGKey(1), params, sample_shape=(1000,)
#       <a href='vscode-notebook-cell:/Users/victorlhoste/Desktop/Multiple_sub_groups_Pyro_git/Git/Bayeian_clustering_RFs/GMM_multi%20copy.ipynb#ch0000012?line=2'>3</a> )
#
# NameError: name 'params' is not defined

# %%
losses = svi_result.losses
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /Users/victorlhoste/Desktop/Multiple_sub_groups_Pyro_git/Git/Bayeian_clustering_RFs/GMM_multi_theo.ipynb Cell 14' in <module>
# ----> <a href='vscode-notebook-cell:/Users/victorlhoste/Desktop/Multiple_sub_groups_Pyro_git/Git/Bayeian_clustering_RFs/GMM_multi_theo.ipynb#ch0000013?line=0'>1</a> losses = svi_result.losses
#
# NameError: name 'svi_result' is not defined

# %%
pyplot.figure(figsize=(10,3), dpi=100).set_facecolor('white')
pyplot.plot(losses)
pyplot.xlabel('iters')
pyplot.ylabel('loss')
pyplot.yscale('log')
pyplot.title('Convergence of SVI');
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /Users/victorlhoste/Desktop/Multiple_sub_groups_Pyro_git/Git/Bayeian_clustering_RFs/GMM_multi_theo.ipynb Cell 15' in <module>
# ----> <a href='vscode-notebook-cell:/Users/victorlhoste/Desktop/Multiple_sub_groups_Pyro_git/Git/Bayeian_clustering_RFs/GMM_multi_theo.ipynb#ch0000014?line=0'>1</a> pyplot.figure(figsize=(10,3), dpi=100).set_facecolor('white')
#       <a href='vscode-notebook-cell:/Users/victorlhoste/Desktop/Multiple_sub_groups_Pyro_git/Git/Bayeian_clustering_RFs/GMM_multi_theo.ipynb#ch0000014?line=1'>2</a> pyplot.plot(losses)
#       <a href='vscode-notebook-cell:/Users/victorlhoste/Desktop/Multiple_sub_groups_Pyro_git/Git/Bayeian_clustering_RFs/GMM_multi_theo.ipynb#ch0000014?line=2'>3</a> pyplot.xlabel('iters')
#
# NameError: name 'pyplot' is not defined

# %%
pyplot.figure(figsize=(10,4), dpi=100).set_facecolor('white')
for name, grad_norms in gradient_norms.items():
    pyplot.plot(grad_norms, label=name)
pyplot.xlabel('iters')
pyplot.ylabel('gradient norm')
pyplot.yscale('log')
pyplot.legend(loc='best')
pyplot.title('Gradient norms during SVI');

# %%
map_estimates = global_guide(data)
weights = map_estimates['weights']
#locs = map_estimates['locs']
#scale = map_estimates['scale']
print('weights = {}'.format(weights.data.numpy()))
#print('locs = {}'.format(locs.data.numpy()))
#print('scale = {}'.format(scale.data.numpy()))
# Out:
# weights = [0.41000125 0.5899987 ]

# %%
map_estimates
# Out:
# {'weights': tensor([0.4100, 0.5900], grad_fn=<ExpandBackward0>),
#  'scale': tensor(0.8503, grad_fn=<ExpandBackward0>)}

# %%
# Out:
# seed = 24, initial_loss = 219761.921875

# %%
# Out:
# ...................................................................................................
# ...................................................................................................
# ...................................................................................................
# ...................................................................................................

# %%
# Out:
# weights = [0.28499213 0.28438357 0.26362866 0.16699558]
# locs = [176.93169 168.25066 159.85153 159.48698]
# scale = 7.042628288269043
